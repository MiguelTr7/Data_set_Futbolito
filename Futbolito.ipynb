# %%
# %load_ext kedro.ipython
# Out:
# The kedro.ipython extension is already loaded. To reload it, use:
#   %reload_ext kedro.ipython

# %%
print(list(catalog.datasets))

# %%
# Prueba así (tal cual aparece en tu catalog.yml):
df_paises = catalog.load("country")
# Out:
# [04/21/26 15:27:18] INFO     Loading data from country (SQLTableDataset)...                    ]8;id=12091302;file://C:\Users\W608-PCXX\futbolito\.venv\Lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=12091303;file://C:\Users\W608-PCXX\futbolito\.venv\Lib\site-packages\kedro\io\data_catalog.py#1053\1053]8;;\
